# %% [markdown]
# Data profiling is the process of examining and analyzing data to understand its structure, quality, and content. It involves extracting metadata and statistics from a dataset to gain insights into its characteristics and properties. Data profiling is an essential step in data preparation and analysis, especially in data-driven applications and decision-making processes.

# %%
# !pip install dataprofiler
# Out:
# Collecting dataprofiler
#   Downloading DataProfiler-0.10.9-py3-none-any.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (3.9.0)
# Requirement already satisfied: wheel>=0.33.1 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (0.43.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (1.25.2)
# Requirement already satisfied: pandas>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.7.5 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (2023.4)
# Requirement already satisfied: pyarrow>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (14.0.2)
# Requirement already satisfied: chardet>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (5.2.0)
# Collecting fastavro>=1.0.0.post1 (from dataprofiler)
#   Downloading fastavro-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 46.1 MB/s eta 0:00:00
# Collecting python-snappy>=0.5.4 (from dataprofiler)
#   Downloading python_snappy-0.7.1-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: charset-normalizer>=1.3.6 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (3.3.2)
# Requirement already satisfied: psutil>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (5.9.5)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (1.11.4)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (2.31.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (3.3)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (4.11.0)
# Collecting HLL>=2.0.3 (from dataprofiler)
#   Downloading HLL-2.0.3.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting datasketches>=4.1.0 (from dataprofiler)
#   Downloading datasketches-5.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (678 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 678.5/678.5 kB 42.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.10/dist-packages (from dataprofiler) (24.0)
# Collecting boto3>=1.28.61 (from dataprofiler)
#   Downloading boto3-1.34.84-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 12.6 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.84 (from boto3>=1.28.61->dataprofiler)
#   Downloading botocore-1.34.84-py3-none-any.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 36.9 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.28.61->dataprofiler)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.28.61->dataprofiler)
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.2->dataprofiler) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.5->dataprofiler) (1.16.0)
# Collecting cramjam (from python-snappy>=0.5.4->dataprofiler)
#   Downloading cramjam-2.8.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 39.6 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->dataprofiler) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->dataprofiler) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->dataprofiler) (2024.2.2)
# Building wheels for collected packages: HLL
#   Building wheel for HLL (setup.py) ... done
#   Created wheel for HLL: filename=HLL-2.0.3-cp310-cp310-linux_x86_64.whl size=30993 sha256=9a019f68c6282bfd9a58eaf094543847cbeac080bd149d1cbcabb20ab5dcba0f
#   Stored in directory: /root/.cache/pip/wheels/29/dd/c2/485a0bf3a7c12be1330ee29caade82df0fd570ed7dbf1e8b22
# Successfully built HLL
# Installing collected packages: HLL, jmespath, fastavro, datasketches, cramjam, python-snappy, botocore, s3transfer, boto3, dataprofiler
# Successfully installed HLL-2.0.3 boto3-1.34.84 botocore-1.34.84 cramjam-2.8.3 dataprofiler-0.10.9 datasketches-5.0.2 fastavro-1.9.4 jmespath-1.0.1 python-snappy-0.7.1 s3transfer-0.10.1

# %%
import json
import pandas as pd
from dataprofiler import Data, Profiler

# %%
# Loading a File
data = Data("/content/googleplaystore.csv") # Auto-Detect & Load: CSV, AVRO, Parquet, JSON, Text
data.data.head(5) # Access data directly via a compatible Pandas DataFrame
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# Sort the data by the neighbourhood column
host = data.data.sort_values(by='Category')
host.head(5)
# Out:
#                                                   App        Category Rating  \
# 10472         Life Made WI-Fi Touchscreen Photo Frame             1.9     19
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 35                   How to draw Ladybug and Cat Noir  ART_AND_DESIGN    3.8
# 36     UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN    4.7
# 37                                 Floor Plan Creator  ART_AND_DESIGN    4.1
#
#       Reviews                Size    Installs  Type     Price Content Rating  \
# 10472    3.0M              1,000+        Free     0  Everyone
# 0         159                 19M     10,000+  Free         0       Everyone
# 35        564                9.2M    100,000+  Free         0       Everyone
# 36       8145                 24M    500,000+  Free         0       Everyone
# 37      36639  Varies with device  5,000,000+  Free         0       Everyone
#
#                         Genres     Last Updated         Current Ver  \
# 10472        February 11, 2018           1.0.19          4.0 and up
# 0                 Art & Design  January 7, 2018               1.0.0
# 35                Art & Design    July 11, 2018                 2.1
# 36     Art & Design;Creativity   August 2, 2018               1.0.9
# 37                Art & Design    July 14, 2018  Varies with device
#
#         Android Ver
# 10472
# 0      4.0.3 and up
# 35       4.1 and up
# 36       4.4 and up
# 37     2.3.3 and up

# %%
print(data.data.shape[0])
len(host[host['Category']!=""])
# Out:
# 10841
# 10841

# %%
# Profile the dataset
profile = Profiler(data) # Calculate Statistics, Entity Recognition, etc

# Generate a report and use json to prettify.
report  = profile.report(report_options={"output_format":"pretty"})

# Print the report
print(json.dumps(report, indent=4))
# Out:
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...
# /usr/local/lib/python3.10/dist-packages/dataprofiler/profilers/profile_builder.py:2903: UserWarning: The data will be profiled with a sample size of 5000. All statistics will be based on this subsample and not the whole dataset.
#   warnings.warn(
# INFO:DataProfiler.profilers.profile_builder:Finding the Null values in the columns...
# 100%|██████████| 13/13 [00:00<00:00, 85.13it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...
# INFO:DataProfiler.profilers.profile_builder:Calculating the statistics...
#  54%|█████▍    | 7/13 [00:02<00:01,  3.21it/s]WARNING:tensorflow:5 out of the last 8 calls to <function TensorFlowOpLayer._defun_call at 0x791e811f43a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#  77%|███████▋  | 10/13 [00:03<00:00,  3.87it/s]WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowOpLayer._defun_call at 0x791e811f43a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 100%|██████████| 13/13 [00:04<00:00,  2.67it/s]
# {
#     "global_stats": {
#         "samples_used": 5000,
#         "column_count": 13,
#         "row_count": 10841,
#         "row_has_null_ratio": 0.136,
#         "row_is_null_ratio": 0.0,
#         "unique_row_ratio": 0.9554,
#         "duplicate_row_count": 483,
#         "file_type": "csv",
#         "encoding": "utf-8",
#         "correlation_matrix": null,
#         "chi2_matrix": "[[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], ... , [nan,  0.,  0., nan,  0.,  0.,  0.,  0.,  0.,  0., nan, nan,  1.]]",
#         "profile_schema": {
#             "App": [
#                 0
#             ],
#             "Category": [
#                 1
#             ],
#             "Rating": [
#                 2
#             ],
#             "Reviews": [
#                 3
#             ],
#             "Size": [
#                 4
#             ],
#             "Installs": [
#                 5
#             ],
#             "Type": [
#                 6
#             ],
#             "Price": [
#                 7
#             ],
#             "Content Rating": [
#                 8
#             ],
#             "Genres": [
#                 9
#             ],
#             "Last Updated": [
#                 10
#             ],
#             "Current Ver": [
#                 11
#             ],
#             "Android Ver": [
#                 12
#             ]
#         },
#         "times": {
#             "row_stats": 0.0383
#         }
#     },
#     "data_stats": [
#         {
#             "column_name": "App",
#             "data_type": "string",
#             "data_label": "UNKNOWN",
#             "categorical": false,
#             "order": "random",
#             "samples": "['Flightradar24 Flight Tracker', 'Doomsday Preppers\u2122',\n 'Weather Radar Widget', 'BZ Langenthaler Tagblatt E-Paper',\n 'Mapy.cz - Cycling & Hiking offline maps']",
#             "statistics": {
#                 "min": 2.0,
#                 "max": 113.0,
#                 "mode": "[30.0275]",
#                 "median": 21.0009,
#                 "sum": 111802.0,
#                 "mean": 22.3604,
#                 "variance": 146.9735,
#                 "stddev": 12.1233,
#                 "skewness": 1.0076,
#                 "kurtosis": 1.9294,
#                 "histogram": {
#                     "bin_edges": "[2.  , 3.85, 5.7 , 7.55, ... , 107.45, 109.3 , 111.15, 113.  ]",
#                     "bin_counts": "[ 41.,  62., 194., 350., 367., ... , 1., 0., 1., 0., 1.]"
#                 },
#                 "quantiles": {
#                     "0": 13.0216,
#                     "1": 21.0009,
#                     "2": 29.0113
#                 },
#                 "median_abs_deviation": 7.996,
#                 "times": {
#                     "vocab": 0.0043,
#                     "min": 0.0003,
#                     "max": 0.0002,
#                     "sum": 0.0002,
#                     "variance": 0.0003,
#                     "skewness": 0.002,
#                     "kurtosis": 0.0016,
#                     "histogram_and_quantiles": 0.0038,
#                     "data_labeler_predict": 0.7582
#                 },
#                 "vocab": "['\u09b2', '\u062d', '\\u3000', '\ud83d\udc8e', ... , '\u0622', '\u4e0d', '\u092a', '2']",
#                 "unique_count": 4693,
#                 "unique_ratio": 0.9386,
#                 "avg_predictions": {
#                     "UNKNOWN": 0.9161,
#                     "ADDRESS": 0.0028,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0004,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0003,
#                     "EMAIL_ADDRESS": 0.0002,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0585,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0025,
#                     "US_STATE": 0.0036,
#                     "INTEGER": 0.006,
#                     "FLOAT": 0.0006,
#                     "QUANTITY": 0.0045,
#                     "ORDINAL": 0.0045
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.944,
#                     "ADDRESS": 0.001,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.048,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.001,
#                     "US_STATE": 0.001,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.001,
#                     "QUANTITY": 0.003,
#                     "ORDINAL": 0.001
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Category",
#             "data_type": "string",
#             "data_label": "UNKNOWN",
#             "categorical": true,
#             "order": "random",
#             "samples": "['PRODUCTIVITY', 'TOOLS', 'MEDICAL', 'FAMILY', 'DATING']",
#             "statistics": {
#                 "min": 4.0,
#                 "max": 19.0,
#                 "mode": "[6.0025]",
#                 "median": 7.0061,
#                 "sum": 45051.0,
#                 "mean": 9.0102,
#                 "variance": 20.5674,
#                 "stddev": 4.5351,
#                 "skewness": 0.8842,
#                 "kurtosis": -0.5478,
#                 "histogram": {
#                     "bin_edges": "[4.        , 4.78947368, ... , 18.21052632, 19.        ]",
#                     "bin_counts": "[ 521.,  388., 1412.,  443., ... , 128.,  37., 333., 159.]"
#                 },
#                 "quantiles": {
#                     "0": 5.9986,
#                     "1": 7.0061,
#                     "2": 13.0013
#                 },
#                 "median_abs_deviation": 2.0031,
#                 "times": {
#                     "vocab": 0.0013,
#                     "min": 0.0002,
#                     "max": 0.0001,
#                     "sum": 0.0001,
#                     "variance": 0.0002,
#                     "skewness": 0.0033,
#                     "kurtosis": 0.0021,
#                     "histogram_and_quantiles": 0.003,
#                     "data_labeler_predict": 0.2298
#                 },
#                 "vocab": "['D', 'N', 'C', 'Y', 'P', ... , 'A', 'F', 'E', 'R', 'S']",
#                 "unique_count": 33,
#                 "unique_ratio": 0.0066,
#                 "categories": "['FAMILY', 'GAME', 'TOOLS', ... , 'EVENTS', 'PARENTING', 'BEAUTY']",
#                 "gini_impurity": 0.9311,
#                 "unalikeability": 0.9313,
#                 "categorical_count": {
#                     "FAMILY": 915,
#                     "GAME": 521,
#                     "TOOLS": 388,
#                     "MEDICAL": 225,
#                     "BUSINESS": 215,
#                     "PRODUCTIVITY": 206,
#                     "PERSONALIZATION": 189,
#                     "SPORTS": 183,
#                     "FINANCE": 172,
#                     "LIFESTYLE": 165,
#                     "COMMUNICATION": 161,
#                     "HEALTH_AND_FITNESS": 160,
#                     "PHOTOGRAPHY": 147,
#                     "NEWS_AND_MAGAZINES": 138,
#                     "SOCIAL": 138,
#                     "TRAVEL_AND_LOCAL": 128,
#                     "SHOPPING": 127,
#                     "BOOKS_AND_REFERENCE": 104,
#                     "DATING": 102,
#                     "VIDEO_PLAYERS": 81,
#                     "EDUCATION": 75,
#                     "ENTERTAINMENT": 66,
#                     "FOOD_AND_DRINK": 56,
#                     "MAPS_AND_NAVIGATION": 55,
#                     "WEATHER": 46,
#                     "HOUSE_AND_HOME": 42,
#                     "AUTO_AND_VEHICLES": 37,
#                     "LIBRARIES_AND_DEMO": 35,
#                     "COMICS": 27,
#                     "ART_AND_DESIGN": 25,
#                     "EVENTS": 24,
#                     "PARENTING": 24,
#                     "BEAUTY": 23
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 0.9998,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0002
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 1.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Rating",
#             "data_type": "float",
#             "data_label": "ORDINAL",
#             "categorical": true,
#             "order": "random",
#             "samples": "['4.5', '4.9', '4.4', '3.5', '3.0']",
#             "statistics": {
#                 "min": 1.0,
#                 "max": 5.0,
#                 "mode": "[4.402]",
#                 "median": 4.2978,
#                 "sum": 18146.6,
#                 "mean": 4.1967,
#                 "variance": 0.2683,
#                 "stddev": 0.518,
#                 "skewness": -1.847,
#                 "kurtosis": 5.767,
#                 "histogram": {
#                     "bin_edges": "[1.        , 1.06060606, ... , 4.93939394, 5.        ]",
#                     "bin_counts": "[7., 0., 0., 0., 0., ... , 229., 116.,   0.,  46., 139.]"
#                 },
#                 "quantiles": {
#                     "0": 4.0028,
#                     "1": 4.2978,
#                     "2": 4.5025
#                 },
#                 "median_abs_deviation": 0.2054,
#                 "num_zeros": 0,
#                 "num_negatives": 0,
#                 "times": {
#                     "precision": 0.0103,
#                     "min": 0.0002,
#                     "max": 0.0001,
#                     "sum": 0.0001,
#                     "variance": 0.0002,
#                     "skewness": 0.0015,
#                     "kurtosis": 0.0014,
#                     "histogram_and_quantiles": 0.0029,
#                     "num_zeros": 0.0003,
#                     "num_negatives": 0.0002,
#                     "data_labeler_predict": 0.1566
#                 },
#                 "precision": {
#                     "min": 1.0,
#                     "max": 2.0,
#                     "mean": 1.9,
#                     "var": 0.096,
#                     "std": 0.31,
#                     "sample_size": 4324,
#                     "margin_of_error": 0.015,
#                     "confidence_level": 0.999
#                 },
#                 "unique_count": 38,
#                 "unique_ratio": 0.0088,
#                 "categories": "['4.4', '4.5', '4.3', '4.2', ... , '1.4', '2.1', '1.5', '1.6']",
#                 "gini_impurity": 0.9242,
#                 "unalikeability": 0.9244,
#                 "categorical_count": {
#                     "4.4": 520,
#                     "4.5": 482,
#                     "4.3": 477,
#                     "4.2": 444,
#                     "4.6": 369,
#                     "4.1": 340,
#                     "4.0": 273,
#                     "4.7": 229,
#                     "3.9": 156,
#                     "5.0": 139,
#                     "3.8": 131,
#                     "4.8": 116,
#                     "3.7": 108,
#                     "3.6": 85,
#                     "3.5": 77,
#                     "3.4": 55,
#                     "4.9": 46,
#                     "3.0": 40,
#                     "3.3": 39,
#                     "3.2": 36,
#                     "2.9": 26,
#                     "3.1": 26,
#                     "2.8": 16,
#                     "2.5": 12,
#                     "2.6": 11,
#                     "2.3": 11,
#                     "2.4": 11,
#                     "2.7": 10,
#                     "1.0": 7,
#                     "2.2": 6,
#                     "1.9": 4,
#                     "2.0": 4,
#                     "1.8": 4,
#                     "1.7": 4,
#                     "1.4": 3,
#                     "2.1": 3,
#                     "1.5": 2,
#                     "1.6": 2
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 0.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.005,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.995
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.004,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.996
#                 },
#                 "sample_size": 5000,
#                 "null_count": 676,
#                 "null_types": "['NaN']",
#                 "null_types_index": {
#                     "NaN": "[126, 129, 479, 620, ... , 10813, 10816, 10822, 10825]"
#                 },
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.1071,
#                     "float": 1.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Reviews",
#             "data_type": "int",
#             "data_label": "INTEGER",
#             "categorical": false,
#             "order": "random",
#             "samples": "['0', '13118', '8259', '2401017', '11549']",
#             "statistics": {
#                 "min": 0.0,
#                 "max": 69109672.0,
#                 "mode": "[2946.85621695]",
#                 "median": 5202.7829,
#                 "sum": 2060068223.0,
#                 "mean": 412013.6446,
#                 "variance": 6286810631309.503,
#                 "stddev": 2507351.3179,
#                 "skewness": 15.7129,
#                 "kurtosis": 332.8071,
#                 "histogram": {
#                     "bin_counts": "[2832,  273,  141, ...,    0,    0,    1]",
#                     "bin_edges": "[   0.        , 5893.71243391, ... , 69103778.2875661, 69109672.       ]"
#                 },
#                 "quantiles": {
#                     "0": 2601.3914,
#                     "1": 5202.7829,
#                     "2": 51078.8411
#                 },
#                 "median_abs_deviation": 0.0,
#                 "num_zeros": 278,
#                 "num_negatives": 0,
#                 "times": {
#                     "min": 0.0002,
#                     "max": 0.0001,
#                     "sum": 0.0001,
#                     "variance": 0.0002,
#                     "skewness": 0.0017,
#                     "kurtosis": 0.0016,
#                     "histogram_and_quantiles": 0.0031,
#                     "num_zeros": 0.0003,
#                     "num_negatives": 0.0002,
#                     "data_labeler_predict": 0.1377
#                 },
#                 "unique_count": 3090,
#                 "unique_ratio": 0.618,
#                 "avg_predictions": {
#                     "UNKNOWN": 0.0,
#                     "ADDRESS": 0.0839,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0651,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.058,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.7931,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.0,
#                     "ADDRESS": 0.075,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.063,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.058,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.804,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.1412,
#                     "int": 1.0,
#                     "float": 1.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Size",
#             "data_type": "string",
#             "data_label": "ORDINAL",
#             "categorical": true,
#             "order": "random",
#             "samples": "['4.6M', '70M', '12M', '5.4M', '21M']",
#             "statistics": {
#                 "min": 3.0,
#                 "max": 18.0,
#                 "mode": "[3.0075]",
#                 "median": 3.9904,
#                 "sum": 28684.0,
#                 "mean": 5.7368,
#                 "variance": 28.6445,
#                 "stddev": 5.3521,
#                 "skewness": 1.8363,
#                 "kurtosis": 1.4244,
#                 "histogram": {
#                     "bin_edges": "[3.        , 3.11627907, ... , 17.88372093, 18.        ]",
#                     "bin_counts": "[2451.,    0.,    0.,    0., ... ,   0.,   0.,   0., 795.]"
#                 },
#                 "quantiles": {
#                     "0": 3.0076,
#                     "1": 3.9904,
#                     "2": 4.0011
#                 },
#                 "median_abs_deviation": 0.98,
#                 "times": {
#                     "vocab": 0.0011,
#                     "min": 0.0002,
#                     "max": 0.0002,
#                     "sum": 0.0002,
#                     "variance": 0.0009,
#                     "skewness": 0.0018,
#                     "kurtosis": 0.0018,
#                     "histogram_and_quantiles": 0.0062,
#                     "data_labeler_predict": 0.1591
#                 },
#                 "vocab": "['a', '5', '6', 'i', '8', ... , '.', '1', 'h', '9', '2']",
#                 "unique_count": 327,
#                 "unique_ratio": 0.0654,
#                 "categories": "['Varies with device', '12M', ... , '206k', '582k']",
#                 "gini_impurity": 0.9686,
#                 "unalikeability": 0.9688,
#                 "categorical_count": {
#                     "Varies with device": 795,
#                     "12M": 104,
#                     "13M": 93,
#                     "14M": 85,
#                     "17M": 80,
#                     "11M": 78,
#                     "15M": 78,
#                     "21M": 71,
#                     "10M": 67,
#                     "19M": 67,
#                     "26M": 66,
#                     "18M": 64,
#                     "20M": 63,
#                     "16M": 63,
#                     "25M": 62,
#                     "22M": 58,
#                     "23M": 57,
#                     "24M": 54,
#                     "29M": 53,
#                     "28M": 52,
#                     "3.3M": 45,
#                     "30M": 45,
#                     "33M": 40,
#                     "37M": 39,
#                     "2.9M": 37,
#                     "31M": 37,
#                     "27M": 36,
#                     "35M": 34,
#                     "48M": 34,
#                     "2.8M": 32,
#                     "3.9M": 31,
#                     "3.1M": 30,
#                     "5.0M": 30,
#                     "2.3M": 29,
#                     "4.2M": 29,
#                     "40M": 29,
#                     "3.2M": 29,
#                     "2.7M": 28,
#                     "4.0M": 28,
#                     "2.5M": 27,
#                     "3.0M": 27,
#                     "43M": 27,
#                     "49M": 26,
#                     "44M": 25,
#                     "3.6M": 25,
#                     "2.4M": 25,
#                     "39M": 24,
#                     "63M": 24,
#                     "4.1M": 24,
#                     "36M": 24,
#                     "1.5M": 24,
#                     "46M": 23,
#                     "38M": 23,
#                     "3.4M": 23,
#                     "32M": 23,
#                     "6.1M": 22,
#                     "57M": 22,
#                     "4.3M": 22,
#                     "2.6M": 22,
#                     "6.3M": 22,
#                     "2.0M": 22,
#                     "34M": 21,
#                     "53M": 21,
#                     "5.1M": 21,
#                     "1.6M": 21,
#                     "3.7M": 21,
#                     "3.5M": 21,
#                     "1.8M": 20,
#                     "50M": 20,
#                     "1.2M": 20,
#                     "6.9M": 20,
#                     "4.4M": 19,
#                     "5.4M": 19,
#                     "59M": 19,
#                     "6.5M": 19,
#                     "4.9M": 19,
#                     "2.2M": 19,
#                     "3.8M": 19,
#                     "41M": 19,
#                     "52M": 18,
#                     "45M": 18,
#                     "67M": 18,
#                     "1.3M": 18,
#                     "60M": 18,
#                     "5.5M": 18,
#                     "5.7M": 18,
#                     "42M": 18,
#                     "4.8M": 17,
#                     "7.0M": 17,
#                     "9.2M": 17,
#                     "1.4M": 17,
#                     "47M": 17,
#                     "5.3M": 17,
#                     "7.3M": 17,
#                     "4.5M": 17,
#                     "5.8M": 17,
#                     "56M": 17,
#                     "6.2M": 17,
#                     "7.6M": 17,
#                     "5.9M": 16,
#                     "8.2M": 16,
#                     "7.9M": 16,
#                     "8.7M": 15,
#                     "51M": 15,
#                     "99M": 15,
#                     "2.1M": 15,
#                     "5.6M": 15,
#                     "62M": 14,
#                     "6.4M": 14,
#                     "5.2M": 14,
#                     "9.8M": 14,
#                     "6.0M": 14,
#                     "6.7M": 14,
#                     "7.2M": 14,
#                     "76M": 14,
#                     "4.7M": 14,
#                     "8.0M": 13,
#                     "1.7M": 13,
#                     "55M": 13,
#                     "1.1M": 13,
#                     "9.0M": 13,
#                     "97M": 13,
#                     "6.6M": 13,
#                     "8.5M": 13,
#                     "1.9M": 13,
#                     "4.6M": 13,
#                     "7.7M": 13,
#                     "8.1M": 12,
#                     "9.9M": 12,
#                     "91M": 12,
#                     "96M": 12,
#                     "9.1M": 12,
#                     "61M": 12,
#                     "8.3M": 12,
#                     "8.9M": 12,
#                     "54M": 12,
#                     "78M": 12,
#                     "7.1M": 12,
#                     "7.4M": 12,
#                     "9.7M": 12,
#                     "58M": 12,
#                     "8.4M": 12,
#                     "6.8M": 12,
#                     "69M": 11,
#                     "70M": 11,
#                     "8.8M": 11,
#                     "9.5M": 10,
#                     "8.6M": 10,
#                     "95M": 10,
#                     "74M": 10,
#                     "64M": 10,
#                     "92M": 9,
#                     "66M": 9,
#                     "71M": 9,
#                     "7.5M": 9,
#                     "72M": 9,
#                     "68M": 9,
#                     "9.3M": 9,
#                     "9.4M": 8,
#                     "77M": 8,
#                     "7.8M": 8,
#                     "81M": 8,
#                     "82M": 8,
#                     "93M": 7,
#                     "85M": 7,
#                     "98M": 7,
#                     "75M": 6,
#                     "94M": 6,
#                     "100M": 6,
#                     "83M": 6,
#                     "79M": 6,
#                     "9.6M": 5,
#                     "65M": 5,
#                     "88M": 5,
#                     "80M": 4,
#                     "10.0M": 4,
#                     "73M": 4,
#                     "90M": 4,
#                     "89M": 3,
#                     "87M": 3,
#                     "1.0M": 2,
#                     "29k": 2,
#                     "84M": 2,
#                     "196k": 2,
#                     "323k": 2,
#                     "266k": 2,
#                     "842k": 2,
#                     "473k": 2,
#                     "70k": 2,
#                     "86M": 2,
#                     "201k": 2,
#                     "144k": 1,
#                     "516k": 1,
#                     "994k": 1,
#                     "775k": 1,
#                     "226k": 1,
#                     "240k": 1,
#                     "157k": 1,
#                     "28k": 1,
#                     "942k": 1,
#                     "33k": 1,
#                     "228k": 1,
#                     "221k": 1,
#                     "601k": 1,
#                     "881k": 1,
#                     "642k": 1,
#                     "837k": 1,
#                     "986k": 1,
#                     "143k": 1,
#                     "643k": 1,
#                     "787k": 1,
#                     "801k": 1,
#                     "411k": 1,
#                     "44k": 1,
#                     "809k": 1,
#                     "499k": 1,
#                     "353k": 1,
#                     "209k": 1,
#                     "552k": 1,
#                     "153k": 1,
#                     "116k": 1,
#                     "1020k": 1,
#                     "743k": 1,
#                     "309k": 1,
#                     "72k": 1,
#                     "485k": 1,
#                     "914k": 1,
#                     "141k": 1,
#                     "376k": 1,
#                     "51k": 1,
#                     "970k": 1,
#                     "192k": 1,
#                     "39k": 1,
#                     "879k": 1,
#                     "79k": 1,
#                     "161k": 1,
#                     "364k": 1,
#                     "860k": 1,
#                     "73k": 1,
#                     "658k": 1,
#                     "154k": 1,
#                     "518k": 1,
#                     "24k": 1,
#                     "280k": 1,
#                     "992k": 1,
#                     "784k": 1,
#                     "981k": 1,
#                     "420k": 1,
#                     "874k": 1,
#                     "921k": 1,
#                     "118k": 1,
#                     "523k": 1,
#                     "270k": 1,
#                     "957k": 1,
#                     "500k": 1,
#                     "608k": 1,
#                     "172k": 1,
#                     "812k": 1,
#                     "551k": 1,
#                     "14k": 1,
#                     "540k": 1,
#                     "26k": 1,
#                     "239k": 1,
#                     "371k": 1,
#                     "91k": 1,
#                     "17k": 1,
#                     "78k": 1,
#                     "121k": 1,
#                     "924k": 1,
#                     "818k": 1,
#                     "939k": 1,
#                     "169k": 1,
#                     "45k": 1,
#                     "61k": 1,
#                     "251k": 1,
#                     "865k": 1,
#                     "772k": 1,
#                     "720k": 1,
#                     "853k": 1,
#                     "779k": 1,
#                     "920k": 1,
#                     "525k": 1,
#                     "975k": 1,
#                     "18k": 1,
#                     "862k": 1,
#                     "704k": 1,
#                     "556k": 1,
#                     "334k": 1,
#                     "41k": 1,
#                     "8.5k": 1,
#                     "624k": 1,
#                     "655k": 1,
#                     "238k": 1,
#                     "514k": 1,
#                     "55k": 1,
#                     "191k": 1,
#                     "598k": 1,
#                     "716k": 1,
#                     "982k": 1,
#                     "222k": 1,
#                     "219k": 1,
#                     "948k": 1,
#                     "549k": 1,
#                     "951k": 1,
#                     "963k": 1,
#                     "554k": 1,
#                     "351k": 1,
#                     "208k": 1,
#                     "913k": 1,
#                     "778k": 1,
#                     "506k": 1,
#                     "728k": 1,
#                     "429k": 1,
#                     "478k": 1,
#                     "459k": 1,
#                     "417k": 1,
#                     "383k": 1,
#                     "350k": 1,
#                     "175k": 1,
#                     "904k": 1,
#                     "306k": 1,
#                     "308k": 1,
#                     "609k": 1,
#                     "210k": 1,
#                     "954k": 1,
#                     "206k": 1,
#                     "582k": 1
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 0.1488,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0001,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0001,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0098,
#                     "FLOAT": 0.0007,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.8406
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.149,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.007,
#                     "FLOAT": 0.001,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.843
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Installs",
#             "data_type": "string",
#             "data_label": "INTEGER",
#             "categorical": true,
#             "order": "random",
#             "samples": "['10,000+', '10,000+', '500+', '10,000+', '1,000,000+']",
#             "statistics": {
#                 "min": 2.0,
#                 "max": 14.0,
#                 "mode": "[9.998]",
#                 "median": 8.0048,
#                 "sum": 39552.0,
#                 "mean": 7.9104,
#                 "variance": 7.1242,
#                 "stddev": 2.6691,
#                 "skewness": -0.3173,
#                 "kurtosis": -0.8018,
#                 "histogram": {
#                     "bin_edges": "[2.        , 2.46153846, ... , 13.53846154, 14.        ]",
#                     "bin_counts": "[ 75.,   0., 274.,   0., 483., ... , 205.,   0.,   0.,   0.,  31.]"
#                 },
#                 "quantiles": {
#                     "0": 6.0038,
#                     "1": 8.0048,
#                     "2": 10.0006
#                 },
#                 "median_abs_deviation": 1.9977,
#                 "times": {
#                     "vocab": 0.0012,
#                     "min": 0.0002,
#                     "max": 0.0001,
#                     "sum": 0.0001,
#                     "variance": 0.0002,
#                     "skewness": 0.0017,
#                     "kurtosis": 0.0016,
#                     "histogram_and_quantiles": 0.0032,
#                     "data_labeler_predict": 0.1567
#                 },
#                 "vocab": "['5', '0', '+', '1', ',']",
#                 "unique_count": 20,
#                 "unique_ratio": 0.004,
#                 "categories": "['1,000,000+', '10,000,000+', ... , '1,000,000,000+', '0+']",
#                 "gini_impurity": 0.9163,
#                 "unalikeability": 0.9165,
#                 "categorical_count": {
#                     "1,000,000+": 750,
#                     "10,000,000+": 575,
#                     "100,000+": 526,
#                     "10,000+": 480,
#                     "1,000+": 423,
#                     "5,000,000+": 348,
#                     "100+": 336,
#                     "500,000+": 255,
#                     "50,000+": 228,
#                     "5,000+": 222,
#                     "10+": 181,
#                     "100,000,000+": 170,
#                     "500+": 147,
#                     "50,000,000+": 125,
#                     "50+": 93,
#                     "500,000,000+": 35,
#                     "1+": 35,
#                     "5+": 34,
#                     "1,000,000,000+": 31,
#                     "0+": 6
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 0.0135,
#                     "ADDRESS": 0.0011,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0001,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.8186,
#                     "FLOAT": 0.1503,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0164
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.846,
#                     "FLOAT": 0.139,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.015
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Type",
#             "data_type": "string",
#             "data_label": "UNKNOWN",
#             "categorical": true,
#             "order": "random",
#             "samples": "['Free', 'Free', 'Free', 'Free', 'Free']",
#             "statistics": {
#                 "min": 4.0,
#                 "max": 4.0,
#                 "mode": "[4.]",
#                 "median": 4.0,
#                 "sum": 20000.0,
#                 "mean": 4.0,
#                 "variance": 0.0,
#                 "stddev": 0.0,
#                 "skewness": 0.0,
#                 "kurtosis": -3.0018,
#                 "histogram": {
#                     "bin_counts": "[5000]",
#                     "bin_edges": "[4., 4.]"
#                 },
#                 "quantiles": {
#                     "0": 4.0,
#                     "1": 4.0,
#                     "2": 4.0
#                 },
#                 "median_abs_deviation": 0.0,
#                 "times": {
#                     "vocab": 0.0008,
#                     "min": 0.0002,
#                     "max": 0.0002,
#                     "sum": 0.0003,
#                     "variance": 0.0002,
#                     "skewness": 0.0017,
#                     "kurtosis": 0.0015,
#                     "histogram_and_quantiles": 0.0017,
#                     "data_labeler_predict": 0.1202
#                 },
#                 "vocab": "['a', 'i', 'F', 'e', 'r', 'd', 'P']",
#                 "unique_count": 2,
#                 "unique_ratio": 0.0004,
#                 "categories": "['Free', 'Paid']",
#                 "gini_impurity": 0.1374,
#                 "unalikeability": 0.1374,
#                 "categorical_count": {
#                     "Free": 4629,
#                     "Paid": 371
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 1.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 1.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Price",
#             "data_type": "string",
#             "data_label": "INTEGER",
#             "categorical": true,
#             "order": "random",
#             "samples": "['0', '0', '0', '0', '0']",
#             "statistics": {
#                 "min": 1.0,
#                 "max": 7.0,
#                 "mode": "[1.003]",
#                 "median": 1.0032,
#                 "sum": 6538.0,
#                 "mean": 1.3076,
#                 "variance": 1.1932,
#                 "stddev": 1.0923,
#                 "skewness": 3.3207,
#                 "kurtosis": 9.2751,
#                 "histogram": {
#                     "bin_edges": "[1.        , 1.42857143, ... , 6.57142857, 7.        ]",
#                     "bin_counts": "[4629.,    0.,    0.,    0., ... ,  0., 38.,  0.,  8.]"
#                 },
#                 "quantiles": {
#                     "0": 1.0016,
#                     "1": 1.0032,
#                     "2": 1.0049
#                 },
#                 "median_abs_deviation": 0.0,
#                 "times": {
#                     "vocab": 0.0006,
#                     "min": 0.0001,
#                     "max": 0.0001,
#                     "sum": 0.0001,
#                     "variance": 0.0002,
#                     "skewness": 0.0016,
#                     "kurtosis": 0.002,
#                     "histogram_and_quantiles": 0.0024,
#                     "data_labeler_predict": 0.1229
#                 },
#                 "vocab": "['7', '5', '0', '6', '8', ... , '.', '1', '9', '$', '2']",
#                 "unique_count": 62,
#                 "unique_ratio": 0.0124,
#                 "categories": "['0', '$0.99', '$2.99', ... , '$389.99', '$19.90', '$1.04']",
#                 "gini_impurity": 0.1424,
#                 "unalikeability": 0.1424,
#                 "categorical_count": {
#                     "0": 4629,
#                     "$0.99": 75,
#                     "$2.99": 57,
#                     "$3.99": 34,
#                     "$1.99": 34,
#                     "$4.99": 30,
#                     "$1.49": 21,
#                     "$2.49": 12,
#                     "$9.99": 9,
#                     "$5.99": 8,
#                     "$6.99": 6,
#                     "$3.49": 6,
#                     "$14.99": 6,
#                     "$24.99": 5,
#                     "$4.49": 5,
#                     "$12.99": 4,
#                     "$6.49": 3,
#                     "$5.49": 3,
#                     "$29.99": 3,
#                     "$19.99": 2,
#                     "$7.99": 2,
#                     "$8.49": 2,
#                     "$16.99": 2,
#                     "$79.99": 2,
#                     "$399.99": 2,
#                     "$11.99": 2,
#                     "$1.00": 1,
# ...
#                     "Parenting;Education": 4,
#                     "Sports;Action & Adventure": 3,
#                     "Educational;Creativity": 3,
#                     "Role Playing;Pretend Play": 3,
#                     "Simulation;Education": 3,
#                     "Entertainment;Brain Games": 3,
#                     "Education;Action & Adventure": 3,
#                     "Music;Music & Video": 3,
#                     "Casual;Creativity": 3,
#                     "Card;Action & Adventure": 2,
#                     "Parenting;Music & Video": 2,
#                     "Books & Reference;Education": 2,
#                     "Education;Brain Games": 2,
#                     "Casual;Education": 2,
#                     "Simulation;Pretend Play": 2,
#                     "Educational;Brain Games": 2,
#                     "Puzzle;Creativity": 2,
#                     "Educational;Action & Adventure": 2,
#                     "Casual;Music & Video": 2,
#                     "Adventure;Education": 2,
#                     "Board;Action & Adventure": 1,
#                     "Racing;Pretend Play": 1,
#                     "Role Playing;Education": 1,
#                     "Puzzle;Education": 1,
#                     "Books & Reference;Creativity": 1,
#                     "Strategy;Action & Adventure": 1,
#                     "Lifestyle;Education": 1,
#                     "Arcade;Pretend Play": 1,
#                     "Travel & Local;Action & Adventure": 1,
#                     "Tools;Education": 1,
#                     "Entertainment;Action & Adventure": 1,
#                     "Art & Design;Pretend Play": 1,
#                     "Video Players & Editors;Creativity": 1,
#                     "Art & Design;Creativity": 1
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 0.9851,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0149,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.979,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.021,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Last Updated",
#             "data_type": "datetime",
#             "data_label": "DATE",
#             "categorical": false,
#             "order": "random",
#             "samples": "['July 12, 2018', 'May 3, 2018', 'June 7, 2017', 'May 19, 2018',\n 'July 5, 2018']",
#             "statistics": {
#                 "min": "May 21, 2010",
#                 "max": "August 7, 2018",
#                 "histogram": null,
#                 "format": "['%B %d, %Y']",
#                 "times": {
#                     "datetime": 0.497,
#                     "data_labeler_predict": 0.2246
#                 },
#                 "unique_count": 1045,
#                 "unique_ratio": 0.209,
#                 "avg_predictions": {
#                     "UNKNOWN": 0.0434,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.9196,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0002,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0073,
#                     "SSN": 0.0055,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0238,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0003,
#                     "ORDINAL": 0.0
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.039,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.938,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.006,
#                     "SSN": 0.006,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.011,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "sample_size": 5000,
#                 "null_count": 0,
#                 "null_types": [],
#                 "null_types_index": {},
#                 "data_type_representation": {
#                     "datetime": 1.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Current Ver",
#             "data_type": "string",
#             "data_label": "ORDINAL",
#             "categorical": false,
#             "order": "random",
#             "samples": "['1.0', '1.0.2', '4.1.0.1', 'Varies with device', '1.0.7']",
#             "statistics": {
#                 "min": 1.0,
#                 "max": 50.0,
#                 "mode": "[4.9935]",
#                 "median": 4.9967,
#                 "sum": 34416.0,
#                 "mean": 6.8887,
#                 "variance": 25.8094,
#                 "stddev": 5.0803,
#                 "skewness": 1.6547,
#                 "kurtosis": 2.1217,
#                 "histogram": {
#                     "bin_edges": "[1.        , 1.46666667, ... , 49.53333333, 50.        ]",
#                     "bin_counts": "[  35.,    0.,   21.,    0., 1244., ... , 0., 0., 0., 0., 1.]"
#                 },
#                 "quantiles": {
#                     "0": 3.007,
#                     "1": 4.9967,
#                     "2": 6.9962
#                 },
#                 "median_abs_deviation": 1.9913,
#                 "times": {
#                     "vocab": 0.0012,
#                     "min": 0.0001,
#                     "max": 0.0001,
#                     "sum": 0.0001,
#                     "variance": 0.0002,
#                     "skewness": 0.0017,
#                     "kurtosis": 0.0016,
#                     "histogram_and_quantiles": 0.0026,
#                     "data_labeler_predict": 0.1667
#                 },
#                 "vocab": "['a', 'i', 'x', 's', 'e', ... , 'F', 'R', '\u2013', '9', '2']",
#                 "unique_count": 1689,
#                 "unique_ratio": 0.3381,
#                 "avg_predictions": {
#                     "UNKNOWN": 0.1385,
#                     "ADDRESS": 0.0013,
#                     "BAN": 0.0001,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0004,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0452,
#                     "IPV6": 0.0003,
#                     "MAC_ADDRESS": 0.0002,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.004,
#                     "SSN": 0.0,
#                     "URL": 0.0001,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.015,
#                     "FLOAT": 0.0944,
#                     "QUANTITY": 0.0001,
#                     "ORDINAL": 0.7004
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 0.139,
#                     "ADDRESS": 0.001,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.046,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.004,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.014,
#                     "FLOAT": 0.095,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.701
#                 },
#                 "sample_size": 5000,
#                 "null_count": 4,
#                 "null_types": "['NaN']",
#                 "null_types_index": {
#                     "NaN": "[   15,  6322,  6803, 10342]"
#                 },
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.1241,
#                     "float": 0.3295,
#                     "string": 1.0
#                 }
#             }
#         },
#         {
#             "column_name": "Android Ver",
#             "data_type": "string",
#             "data_label": "UNKNOWN",
#             "categorical": true,
#             "order": "random",
#             "samples": "['4.0 and up', '4.0 and up', 'Varies with device', '4.1 and up',\n '4.0.3 and up']",
#             "statistics": {
#                 "min": 9.0,
#                 "max": 18.0,
#                 "mode": "[10.0035]",
#                 "median": 10.0054,
#                 "sum": 56764.0,
#                 "mean": 11.3573,
#                 "variance": 7.0294,
#                 "stddev": 2.6513,
#                 "skewness": 1.9258,
#                 "kurtosis": 2.108,
#                 "histogram": {
#                     "bin_edges": "[9.        , 9.23076923, ... , 17.76923077, 18.        ]",
#                     "bin_counts": "[1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 3.525e+03, ... ,   0.,   0.,   0.,   0., 641.]"
#                 },
#                 "quantiles": {
#                     "0": 10.0022,
#                     "1": 10.0054,
#                     "2": 11.9994
#                 },
#                 "median_abs_deviation": 0.0038,
#                 "times": {
#                     "vocab": 0.0016,
#                     "min": 0.0003,
#                     "max": 0.0002,
#                     "sum": 0.0003,
#                     "variance": 0.0002,
#                     "skewness": 0.0017,
#                     "kurtosis": 0.0015,
#                     "histogram_and_quantiles": 0.0026,
#                     "data_labeler_predict": 0.1872
#                 },
#                 "vocab": "['a', 'i', '5', '6', '8', ... , '-', '1', 'h', '7', '2']",
#                 "unique_count": 28,
#                 "unique_ratio": 0.0056,
#                 "categories": "['4.1 and up', '4.0.3 and up', ... , '2.2 - 7.1.1', '5.0 - 7.1.1']",
#                 "gini_impurity": 0.8802,
#                 "unalikeability": 0.8804,
#                 "categorical_count": {
#                     "4.1 and up": 1111,
#                     "4.0.3 and up": 692,
#                     "Varies with device": 641,
#                     "4.0 and up": 621,
#                     "4.4 and up": 470,
#                     "5.0 and up": 286,
#                     "2.3 and up": 285,
#                     "4.2 and up": 184,
#                     "2.3.3 and up": 131,
#                     "2.2 and up": 122,
#                     "4.3 and up": 109,
#                     "3.0 and up": 109,
#                     "2.1 and up": 57,
#                     "1.6 and up": 51,
#                     "6.0 and up": 29,
#                     "7.0 and up": 20,
#                     "3.2 and up": 20,
#                     "2.0 and up": 15,
#                     "5.1 and up": 14,
#                     "1.5 and up": 13,
#                     "8.0 and up": 4,
#                     "4.4W and up": 3,
#                     "2.0.1 and up": 3,
#                     "3.1 and up": 3,
#                     "7.1 and up": 2,
#                     "5.0 - 6.0": 1,
#                     "2.2 - 7.1.1": 1,
#                     "5.0 - 7.1.1": 1
#                 },
#                 "avg_predictions": {
#                     "UNKNOWN": 0.7149,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.1982,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.087
#                 },
#                 "data_label_representation": {
#                     "UNKNOWN": 1.0,
#                     "ADDRESS": 0.0,
#                     "BAN": 0.0,
#                     "CREDIT_CARD": 0.0,
#                     "DATE": 0.0,
#                     "TIME": 0.0,
#                     "DATETIME": 0.0,
#                     "DRIVERS_LICENSE": 0.0,
#                     "EMAIL_ADDRESS": 0.0,
#                     "UUID": 0.0,
#                     "HASH_OR_KEY": 0.0,
#                     "IPV4": 0.0,
#                     "IPV6": 0.0,
#                     "MAC_ADDRESS": 0.0,
#                     "PERSON": 0.0,
#                     "PHONE_NUMBER": 0.0,
#                     "SSN": 0.0,
#                     "URL": 0.0,
#                     "US_STATE": 0.0,
#                     "INTEGER": 0.0,
#                     "FLOAT": 0.0,
#                     "QUANTITY": 0.0,
#                     "ORDINAL": 0.0
#                 },
#                 "sample_size": 5000,
#                 "null_count": 2,
#                 "null_types": "['NaN']",
#                 "null_types_index": {
#                     "NaN": "[4453, 4490]"
#                 },
#                 "data_type_representation": {
#                     "datetime": 0.0,
#                     "int": 0.0,
#                     "float": 0.0,
#                     "string": 1.0
#                 }
#             }
#         }
#     ]
# }

# %%
profile = Profiler(data) # Calculate Statistics, Entity Recognition, etc
# Out:
# INFO:DataProfiler.profilers.profile_builder: Finding the Null values in the columns...
# /usr/local/lib/python3.10/dist-packages/dataprofiler/profilers/profile_builder.py:2903: UserWarning: The data will be profiled with a sample size of 5000. All statistics will be based on this subsample and not the whole dataset.
#   warnings.warn(
# INFO:DataProfiler.profilers.profile_builder:Finding the Null values in the columns...
# 100%|██████████| 13/13 [00:00<00:00, 80.39it/s]
# INFO:DataProfiler.profilers.profile_builder: Calculating the statistics...
# INFO:DataProfiler.profilers.profile_builder:Calculating the statistics...
# 100%|██████████| 13/13 [00:04<00:00,  2.92it/s]

# %%
data.describe(include = 'all')
# Out:
#            App Category Rating Reviews                Size    Installs   Type  \
# count    10841    10841  10841   10841               10841       10841  10841
# unique    9660       34     41    6002                 462          22      4
# top     ROBLOX   FAMILY    NaN       0  Varies with device  1,000,000+   Free
# freq         9     1972   1474     596                1695        1579  10039
#
#         Price Content Rating Genres    Last Updated         Current Ver  \
# count   10841          10841  10841           10841               10841
# unique     93              7    120            1378                2834
# top         0       Everyone  Tools  August 3, 2018  Varies with device
# freq    10040           8714    842             326                1459
#
#        Android Ver
# count        10841
# unique          35
# top     4.1 and up
# freq          2451

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
import pandas as pd

def check_csv_for_issues(df):
    missing_values = df.isnull().sum()
    duplicate_rows = df.duplicated().sum()
    inconsistent_types = df.applymap(type).nunique() > 1

    inconsistent_formats = not pd.to_datetime(df['Last Updated'], errors='coerce').notnull().all()
    rating_outliers = (df['Rating'] < 0) | (df['Rating'] > 5)

    issues_found = False

    if missing_values.any():
        issues_found = True
        print("Columns with missing values:")
        print(missing_values[missing_values > 0])

    if duplicate_rows > 0:
        issues_found = True
        print("Duplicates exists")
    if inconsistent_types.any():
        issues_found = True
        print("Columns with inconsistent data types:")
        print(inconsistent_types[inconsistent_types].index.tolist())
    if inconsistent_formats:
        issues_found = True
        print("Columns with inconsistent data formats:")
        print("You need to customize this part based on your specific data formats")

    if rating_outliers.any():
        issues_found = True
        print("Columns with rating outliers:")
        print("Rating column is affected by rating outliers.")

    if not issues_found:
        print("No issues found in the CSV file. Data cleaning is not needed.")

csv_file = '/content/googleplaystore.csv'

df = pd.read_csv(csv_file)

check_csv_for_issues(df)
# Out:
# Columns with missing values:
# Rating            1474
# Type                 1
# Content Rating       1
# Current Ver          8
# Android Ver          3
# dtype: int64
# Duplicates exists
# Columns with inconsistent data types:
# ['Type', 'Content Rating', 'Current Ver', 'Android Ver']
# Columns with inconsistent data formats:
# You need to customize this part based on your specific data formats
# Columns with rating outliers:
# Rating column is affected by rating outliers.
